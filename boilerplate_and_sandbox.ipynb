# %% [markdown]
# # You're the new CFO of BetterPloof Inc.
#
# The ploof market is booming and you join the race as the CFO of the BetterPloof Inc.
#
# Ploofs can be very different, and there are many different uses.
#
# ### Example Ploof Versions
#
# 1. **Mini Turbo Ploof**: Ultra-compact and high-speed for on-the-go professionals.
# 2. **Solar Pro Ploof**: Medium capacity with solar power for eco-conscious users.
# 3. **Rugged Glow Ploof**: Durable with LED lights for outdoor enthusiasts.
# 4. **Smart Stealth Ploof**: Silent operation with smart technology for tech-savvy users.
# 5. **Luxury Touchscreen Ploof**: Elegant design with a touchscreen interface for high-end consumers.
# 6. **Child-Safe Customizable Ploof**: Safe and modular for families with young children.
# 7. **Retro Voice-Controlled Ploof**: Vintage design with modern voice control for nostalgic tech lovers.
# 8. **Industrial Eco Ploof**: Energy-saving with extra safety for industrial settings.
# 9. **Travel Economy Ploof**: Affordable and compact for frequent travelers.
# 10. **Outdoor Ultra Ploof**: High capacity and weather-resistant for outdoor adventures.
#
# These attributes and versions cater to a wide range of user needs and preferences, making the Ploof a versatile and appealing product for different markets.

# %%
import numpy as np
import pandas as pd
import plotly.express as px
from sklearn.datasets import make_blobs

# making the random simulation determined by seed
rng = np.random.default_rng(seed=42)

# %%
n_population = 20000
n_groups = 16
group_variance = .3

feature_labels = [
    'impact','utilitarism','frugality','safety',
    'comfort','beauty','status','tradition']

# determining n bucket sizes for population with variance %
def create_buckets(population, variance_percentile, n_groups):
  bucket_size = int(population / n_groups)
  variance_value = bucket_size * variance_percentile

  buckets = (
      [bucket_size] * n_groups +
      rng.integers(-variance_value, variance_value+1, size=n_groups)
  )

  buckets[-1] == population - buckets.sum()
  return buckets

# creating
def create_stds(n_groups, min_std=.4, max_std=1.2):
  return rng.uniform(min_std, max_std, size=n_groups)


def create_centers(n_features, n_groups):
  return (
      rng.normal(size=n_features*n_groups)
      .reshape(n_groups, n_features)
  )


def create_population(n_population, n_groups, group_variance, feature_labels):

  n_features = len(feature_labels)
  n_samples = create_buckets(n_population, group_variance, n_groups)
  cluster_centers = create_centers(n_features, n_groups)
  cluster_stds = create_stds(n_groups)

  blobs_X, blobs_y, centers = make_blobs(
        n_features=n_features,
        n_samples=n_samples,
        centers=cluster_centers,
        cluster_std=cluster_stds,
        random_state=rng.integers(0,100),
        return_centers=True
      )

  market = (
      pd.DataFrame(blobs_X, columns=feature_labels)
      .join(
          pd.DataFrame(blobs_y, columns=['persona'])
          )
      )

  market['persona'] = market['persona'].astype('category')

  return market, centers, cluster_stds

market, centers, stds = create_population(
    n_population,
    n_groups,
    group_variance,
    feature_labels
    )

# %%
fig = px.scatter_3d(
    market,
    x='impact',
    y='utilitarism',
    z='frugality',
    color='persona',
    opacity=0.2,
    width=800, height=800,
    )

fig.update(layout_showlegend=False)
fig.update(layout_coloraxis_showscale=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fe94c562-8019-4c89-8b6c-d3e828ef7f23" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f
# %%
(
    pd.DataFrame(centers, columns=feature_labels).T
    .style.background_gradient(cmap='RdBu')
    .set_caption("psychographic group values")

)
# Out:
# <style type="text/css">
# #T_f2c92_row0_col0, #T_f2c92_row0_col6, #T_f2c92_row1_col2, #T_f2c92_row1_col4, #T_f2c92_row5_col1, #T_f2c92_row5_col3, #T_f2c92_row5_col5 {
#   background-color: #67001f;
#   color: #f1f1f1;
# }
# #T_f2c92_row0_col1 {
#   background-color: #f8f4f2;
#   color: #000000;
# }
# #T_f2c92_row0_col2 {
#   background-color: #e8896c;
#   color: #f1f1f1;
# }
# #T_f2c92_row0_col3 {
#   background-color: #fcdfcf;
#   color: #000000;
# }
# #T_f2c92_row0_col4 {
#   background-color: #f9ebe3;
#   color: #000000;
# }
# #T_f2c92_row0_col5 {
#   background-color: #930e26;
#   color: #f1f1f1;
# }
# #T_f2c92_row1_col0 {
#   background-color: #de735c;
#   color: #f1f1f1;
# }
# #T_f2c92_row1_col1, #T_f2c92_row2_col2, #T_f2c92_row2_col3, #T_f2c92_row2_col5, #T_f2c92_row4_col4, #T_f2c92_row5_col6, #T_f2c92_row6_col0 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_f2c92_row1_col3 {
#   background-color: #fce0d0;
#   color: #000000;
# }
# #T_f2c92_row1_col5 {
#   background-color: #d25849;
#   color: #f1f1f1;
# }
# #T_f2c92_row1_col6 {
#   background-color: #fcd3bc;
#   color: #000000;
# }
# #T_f2c92_row2_col0 {
#   background-color: #75b2d4;
#   color: #f1f1f1;
# }
# #T_f2c92_row2_col1 {
#   background-color: #9bc9e0;
#   color: #000000;
# }
# #T_f2c92_row2_col4 {
#   background-color: #6d0220;
#   color: #f1f1f1;
# }
# #T_f2c92_row2_col6 {
#   background-color: #f7b799;
#   color: #000000;
# }
# #T_f2c92_row3_col0 {
#   background-color: #dae9f2;
#   color: #000000;
# }
# #T_f2c92_row3_col1 {
#   background-color: #8a0b25;
#   color: #f1f1f1;
# }
# #T_f2c92_row3_col2, #T_f2c92_row3_col6, #T_f2c92_row6_col5 {
#   background-color: #ec9374;
#   color: #f1f1f1;
# }
# #T_f2c92_row3_col3 {
#   background-color: #bf3338;
#   color: #f1f1f1;
# }
# #T_f2c92_row3_col4 {
#   background-color: #144e8a;
#   color: #f1f1f1;
# }
# #T_f2c92_row3_col5 {
#   background-color: #d35a4a;
#   color: #f1f1f1;
# }
# #T_f2c92_row4_col0 {
#   background-color: #9dcbe1;
#   color: #000000;
# }
# #T_f2c92_row4_col1 {
#   background-color: #bbdaea;
#   color: #000000;
# }
# #T_f2c92_row4_col2 {
#   background-color: #bd2d35;
#   color: #f1f1f1;
# }
# #T_f2c92_row4_col3 {
#   background-color: #b3192c;
#   color: #f1f1f1;
# }
# #T_f2c92_row4_col5 {
#   background-color: #62a7ce;
#   color: #f1f1f1;
# }
# #T_f2c92_row4_col6 {
#   background-color: #fddbc7;
#   color: #000000;
# }
# #T_f2c92_row5_col0 {
#   background-color: #fcd5bf;
#   color: #000000;
# }
# #T_f2c92_row5_col2 {
#   background-color: #cc4c44;
#   color: #f1f1f1;
# }
# #T_f2c92_row5_col4 {
#   background-color: #2a71b2;
#   color: #f1f1f1;
# }
# #T_f2c92_row6_col1 {
#   background-color: #276eb0;
#   color: #f1f1f1;
# }
# #T_f2c92_row6_col2 {
#   background-color: #b8d8e9;
#   color: #000000;
# }
# #T_f2c92_row6_col3 {
#   background-color: #f8f2ef;
#   color: #000000;
# }
# #T_f2c92_row6_col4 {
#   background-color: #b61f2e;
#   color: #f1f1f1;
# }
# #T_f2c92_row6_col6 {
#   background-color: #d6604d;
#   color: #f1f1f1;
# }
# #T_f2c92_row7_col0 {
#   background-color: #0f437b;
#   color: #f1f1f1;
# }
# #T_f2c92_row7_col1 {
#   background-color: #fbe5d8;
#   color: #000000;
# }
# #T_f2c92_row7_col2 {
#   background-color: #e4eef4;
#   color: #000000;
# }
# #T_f2c92_row7_col3 {
#   background-color: #acd2e5;
#   color: #000000;
# }
# #T_f2c92_row7_col4 {
#   background-color: #a0cce2;
#   color: #000000;
# }
# #T_f2c92_row7_col5 {
#   background-color: #90c4dd;
#   color: #000000;
# }
# #T_f2c92_row7_col6 {
#   background-color: #3b88be;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f2c92" class="dataframe">
#   <caption>psychographic group values</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2c92_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_f2c92_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_f2c92_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_f2c92_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_f2c92_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_f2c92_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_f2c92_level0_col6" class="col_heading level0 col6" >6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2c92_level0_row0" class="row_heading level0 row0" >impact</th>
#       <td id="T_f2c92_row0_col0" class="data row0 col0" >-1.951035</td>
#       <td id="T_f2c92_row0_col1" class="data row0 col1" >0.066031</td>
#       <td id="T_f2c92_row0_col2" class="data row0 col2" >-0.184862</td>
#       <td id="T_f2c92_row0_col3" class="data row0 col3" >0.412733</td>
#       <td id="T_f2c92_row0_col4" class="data row0 col4" >-0.113947</td>
#       <td id="T_f2c92_row0_col5" class="data row0 col5" >0.116686</td>
#       <td id="T_f2c92_row0_col6" class="data row0 col6" >-1.457156</td>
#     </tr>
#     <tr>
#       <th id="T_f2c92_level0_row1" class="row_heading level0 row1" >utilitarism</th>
#       <td id="T_f2c92_row1_col0" class="data row1 col0" >-1.302180</td>
#       <td id="T_f2c92_row1_col1" class="data row1 col1" >1.127241</td>
#       <td id="T_f2c92_row1_col2" class="data row1 col2" >-0.680930</td>
#       <td id="T_f2c92_row1_col3" class="data row1 col3" >0.430821</td>
#       <td id="T_f2c92_row1_col4" class="data row1 col4" >-0.840156</td>
#       <td id="T_f2c92_row1_col5" class="data row1 col5" >0.218689</td>
#       <td id="T_f2c92_row1_col6" class="data row1 col6" >-0.319671</td>
#     </tr>
#     <tr>
#       <th id="T_f2c92_level0_row2" class="row_heading level0 row2" >frugality</th>
#       <td id="T_f2c92_row2_col0" class="data row2 col0" >0.127840</td>
#       <td id="T_f2c92_row2_col1" class="data row2 col1" >0.467509</td>
#       <td id="T_f2c92_row2_col2" class="data row2 col2" >1.222541</td>
#       <td id="T_f2c92_row2_col3" class="data row2 col3" >2.141648</td>
#       <td id="T_f2c92_row2_col4" class="data row2 col4" >-0.824481</td>
#       <td id="T_f2c92_row2_col5" class="data row2 col5" >0.871429</td>
#       <td id="T_f2c92_row2_col6" class="data row2 col6" >-0.470373</td>
#     </tr>
#     <tr>
#       <th id="T_f2c92_level0_row3" class="row_heading level0 row3" >safety</th>
#       <td id="T_f2c92_row3_col0" class="data row3 col0" >-0.316243</td>
#       <td id="T_f2c92_row3_col1" class="data row3 col1" >-0.859292</td>
#       <td id="T_f2c92_row3_col2" class="data row3 col2" >-0.154529</td>
#       <td id="T_f2c92_row3_col3" class="data row3 col3" >-0.406415</td>
#       <td id="T_f2c92_row3_col4" class="data row3 col4" >0.650593</td>
#       <td id="T_f2c92_row3_col5" class="data row3 col5" >0.223596</td>
#       <td id="T_f2c92_row3_col6" class="data row3 col6" >-0.638878</td>
#     </tr>
#     <tr>
#       <th id="T_f2c92_level0_row4" class="row_heading level0 row4" >comfort</th>
#       <td id="T_f2c92_row4_col0" class="data row4 col0" >-0.016801</td>
#       <td id="T_f2c92_row4_col1" class="data row4 col1" >0.368751</td>
#       <td id="T_f2c92_row4_col2" class="data row4 col2" >-0.428328</td>
#       <td id="T_f2c92_row4_col3" class="data row4 col3" >-0.512243</td>
#       <td id="T_f2c92_row4_col4" class="data row4 col4" >0.743254</td>
#       <td id="T_f2c92_row4_col5" class="data row4 col5" >0.678914</td>
#       <td id="T_f2c92_row4_col6" class="data row4 col6" >-0.275142</td>
#     </tr>
#     <tr>
#       <th id="T_f2c92_level0_row5" class="row_heading level0 row5" >beauty</th>
#       <td id="T_f2c92_row5_col0" class="data row5 col0" >-0.853044</td>
#       <td id="T_f2c92_row5_col1" class="data row5 col1" >-0.958883</td>
#       <td id="T_f2c92_row5_col2" class="data row5 col2" >-0.352134</td>
#       <td id="T_f2c92_row5_col3" class="data row5 col3" >-0.813773</td>
#       <td id="T_f2c92_row5_col4" class="data row5 col4" >0.543154</td>
#       <td id="T_f2c92_row5_col5" class="data row5 col5" >0.067579</td>
#       <td id="T_f2c92_row5_col6" class="data row5 col6" >1.494941</td>
#     </tr>
#     <tr>
#       <th id="T_f2c92_level0_row6" class="row_heading level0 row6" >status</th>
#       <td id="T_f2c92_row6_col0" class="data row6 col0" >0.879398</td>
#       <td id="T_f2c92_row6_col1" class="data row6 col1" >0.878450</td>
#       <td id="T_f2c92_row6_col2" class="data row6 col2" >0.532309</td>
#       <td id="T_f2c92_row6_col3" class="data row6 col3" >0.615979</td>
#       <td id="T_f2c92_row6_col4" class="data row6 col4" >-0.
